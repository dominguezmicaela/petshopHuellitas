# %% [markdown]
# # Generación de Usuarios

# %% [markdown]
# # Configuración y Conexión

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading faker-40.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from faker) (2025.3)
# Downloading faker-40.1.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.1 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-40.1.0

# %%
import pandas as pd
import random
from faker import Faker
from sqlalchemy import create_engine

# Configura Faker para Argentina
fake = Faker('es_AR')

# Reemplaza con tu cadena de conexión de Neon
DATABASE_URL = "tu_cadena_de_conexion_aqui"
engine = create_engine('URLPRIVADA')
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# /tmp/ipython-input-2915003430.py in <cell line: 0>()
#       9 # Reemplaza con tu cadena de conexión de Neon
#      10 DATABASE_URL = "tu_cadena_de_conexion_aqui"
# ---> 11 engine = create_engine('URLPRIVADA')
#
# <string> in create_engine(url, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     279                         stacklevel=3,
#     280                     )
# --> 281             return fn(*args, **kwargs)  # type: ignore[no-any-return]
#     282
#     283         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# /usr/local/lib/python3.12/dist-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#     562
#     563     # create url.URL object
# --> 564     u = _url.make_url(url)
#     565
#     566     u, plugins, kwargs = u._instantiate_plugins(kwargs)
#
# /usr/local/lib/python3.12/dist-packages/sqlalchemy/engine/url.py in make_url(name_or_url)
#     854
#     855     if isinstance(name_or_url, str):
# --> 856         return _parse_url(name_or_url)
#     857     elif not isinstance(name_or_url, URL) and not hasattr(
#     858         name_or_url, "_sqla_is_testing_if_this_is_a_mock_object"
#
# /usr/local/lib/python3.12/dist-packages/sqlalchemy/engine/url.py in _parse_url(name)
#     920
#     921     else:
# --> 922         raise exc.ArgumentError(
#     923             "Could not parse SQLAlchemy URL from given URL string"
#     924         )
#
# ArgumentError: Could not parse SQLAlchemy URL from given URL string

# %% [markdown]
# # Lógica de Negocio

# %%
# defino segmentos
segmentos = ['CatLover', 'DogLover', 'Aves', 'Exóticos']

def generar_dataset_usuarios(n=15):
    lista_usuarios = []
    for _ in range(n):
        segmento_elegido = random.choice(segmentos)

        lista_usuarios.append({
            "nombre": fake.first_name(),
            "apellido": fake.last_name(),
            "email": fake.email(),
            "passwordHash": "argon2_simulado_5544", # Placeholder para seguridad
            "direccion": fake.address().replace('\n', ', '),
            "segmentoCliente": segmento_elegido,
            "idRol": 2
        })
    return pd.DataFrame(lista_usuarios)

# Generamos los datos en memoria
df_usuarios = generar_dataset_usuarios(20)

# Mostramos un resumen para verificar
print("📊 Previsualización de los usuarios a cargar:")
print(df_usuarios[['nombre', 'apellido','segmentoCliente']].head())
# Out:
# 📊 Previsualización de los usuarios a cargar:
#            nombre   apellido segmentoCliente
# 0    Ian Benjamin      Gomez        DogLover
# 1  Mateo Benjamin     Medina            Aves
# 2           Maite     Garcia        CatLover
# 3           Mateo       Ruiz            Aves
# 4           Sofia  Hernandez            Aves

# %% [markdown]
# # Carga a la base de datos

# %%
nombre_tabla = 'Usuario'

try:
    df_usuarios.to_sql(nombre_tabla, engine, if_exists='append', index=False)
except Exception as e:
    print(f" Error al cargar en la base de datos: {e}")
